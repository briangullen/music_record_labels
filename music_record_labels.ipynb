# %%
pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
#   WARNING: The script tqdm is installed in '/Library/Frameworks/Python.framework/Versions/3.12/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import time
import tqdm
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# %%
df = pd.read_xml('https://discogs-data-dumps.s3-us-west-2.amazonaws.com/data/2023/discogs_20230101_labels.xml.gz')

# %%
df.head()
# Out:
#    images  id                   name  \
# 0     NaN   1               Planet E
# 1     NaN   2  Earthtones Recordings
# 2     NaN   3     Seasons Recordings
# 3     NaN   4           Siesta Music
# 4     NaN   5                   Svek
#
#                                          contactinfo  \
# 0  Planet E Communications\r\nP.O. Box 27218\r\nD...
# 1  Seasons Recordings\r\n2236 Pacific Avenue\r\nS...
# 2  Seasons Recordings\r\nCosta Mesa, CA 92627\r\n...
# 3  Siesta Records\r\n1913 Via Encantadoras\r\nSan...
# 4  Svek office \r\nStephan Grieder \r\nFax: +46 (...
#
#                                              profile data_quality  urls  \
# 0  [a=Carl Craig]'s classic techno label founded ...   Needs Vote   NaN
# 1  California deep house label founded by [a=Jami...      Correct   NaN
# 2  California deep-house label founded by [a=Jami...   Needs Vote   NaN
# 3                                               None   Needs Vote   NaN
# 4                                               None      Correct   NaN
#
#    sublabels     parentLabel
# 0        NaN            None
# 1        NaN            None
# 2        NaN            None
# 3        NaN            None
# 4        NaN  Goldhead Music

# %%
df = df.loc[(df['data_quality'] == 'Complete and Correct')]

# %%
df = df.loc[~(df['contactinfo'].isna())]

# %%
df.head()
# Out:
#       images    id                name  \
# 725      NaN   774   Hed Kandi Records
# 2878     NaN  3141             Concept
# 2935     NaN  3203  Tinnitus Tonträger
# 3020     NaN  3295  Taaach! Recordings
# 3505     NaN  3824                Fuse
#
#                                             contactinfo  \
# 725   MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878  Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935  Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020  Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505  Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
#
#                                                 profile          data_quality  \
# 725   Record company of the UK-based house label [l6...  Complete and Correct
# 2878  Trance label from the UK. The label becomes [l...  Complete and Correct
# 2935          Style: hard kicking minimal techno traxx.  Complete and Correct
# 3020  German Trance Label\r\nDistributed by InterGro...  Complete and Correct
# 3505  German Trance label\r\nDistributed by Music Ma...  Complete and Correct
#
#       urls  sublabels          parentLabel
# 725    NaN        NaN    Ministry Of Sound
# 2878   NaN        NaN  Global Beat Records
# 2935   NaN        NaN                 None
# 3020   NaN        NaN                 None
# 3505   NaN        NaN      Massive Records

# %%
df = df.drop(columns=['images', 'data_quality', 'urls', 'sublabels'])

# %%
df.head()
# Out:
#         id                name  \
# 725    774   Hed Kandi Records
# 2878  3141             Concept
# 2935  3203  Tinnitus Tonträger
# 3020  3295  Taaach! Recordings
# 3505  3824                Fuse
#
#                                             contactinfo  \
# 725   MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878  Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935  Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020  Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505  Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
#
#                                                 profile          parentLabel
# 725   Record company of the UK-based house label [l6...    Ministry Of Sound
# 2878  Trance label from the UK. The label becomes [l...  Global Beat Records
# 2935          Style: hard kicking minimal techno traxx.                 None
# 3020  German Trance Label\r\nDistributed by InterGro...                 None
# 3505  German Trance label\r\nDistributed by Music Ma...      Massive Records

# %%
def get_response(label_id: int):
    token = 'wTaBcAATdLbwuzAgftzyWAaAUlDuRGtGMflXwgVk'
    base_url = f'https://api.discogs.com/labels/{label_id}/releases'
    params = {
        'token': token
    }
    response = requests.get(base_url, params=params).json()
    releases = response['releases']
    return releases

# %%
new_df = pd.DataFrame()
ids = [774, 3141, 3824, 3203]
for label_id in tqdm.tqdm(ids):
    try:
        releases = get_response(label_id)
        successful = True
        time.sleep(1)
    except Exception:
        print(f'Failed request for label_id: {label_id}. Retry in 60 seconds.')
        time.sleep(60)
    num_releases = len(releases)
    years = [release['year'] for release in releases]
    min_year = min(years) if len(years) > 0 else None
    max_year = max(years) if len(years) > 0 else None
    new_row = pd.DataFrame({'id': [label_id], 'num_of_releases': [num_releases], 'min_release_year': [min_year], 'max_release_year': [max_year]})
    new_df = pd.concat([new_df, new_row], axis='rows')
# Out:
# 100%|██████████| 4/4 [00:06<00:00,  1.66s/it]

# %%
new_df
# Out:
#      id  num_of_releases  min_release_year  max_release_year
# 0   774               50              1999              2002
# 0  3141                4              1996              1996
# 0  3824               33              1997              2001
# 0  3203               11                 0              2002

# %%
additional_df = pd.DataFrame()
for label_id in tqdm.tqdm(df['id']):
    successful = False
    try:
        releases = get_response(label_id)
        successful = True
        time.sleep(1)
    except Exception:
        print('Failed to get label_id: {label_id}. Retrying in 60 seconds.')
        time.sleep(60)
    num_releases = len(releases)
    years = [release['year'] for release in releases]
    min_year = min(years) if len(years) > 0 else None
    max_year = max(years) if len(years) > 0 else None
    new_row = pd.DataFrame({'id': [label_id], 'num_of_releases': [num_releases], 'min_release_year': [min_year], 'max_release_year': [max_year]})
    additional_df = pd.concat([additional_df, new_row], axis='rows')
# Out:
# 100%|██████████| 430/430 [12:07<00:00,  1.69s/it]

# %%
additional_df.head()
# Out:
#      id  num_of_releases min_release_year max_release_year
# 0   774               50             1999             2002
# 0  3141                4             1996             1996
# 0  3203               11                0             2002
# 0  3295               29                0             2001
# 0  3824               33             1997             2001

# %%
labels_df = df.merge(additional_df, on='id')

# %%
labels_df.head()
# Out:
#      id                name  \
# 0   774   Hed Kandi Records
# 1  3141             Concept
# 2  3203  Tinnitus Tonträger
# 3  3295  Taaach! Recordings
# 4  3824                Fuse
#
#                                          contactinfo  \
# 0  MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 1  Concept Records\r\n24A Barry Street\r\nBradfor...
# 2  Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3  Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 4  Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
#
#                                              profile          parentLabel  \
# 0  Record company of the UK-based house label [l6...    Ministry Of Sound
# 1  Trance label from the UK. The label becomes [l...  Global Beat Records
# 2          Style: hard kicking minimal techno traxx.                 None
# 3  German Trance Label\r\nDistributed by InterGro...                 None
# 4  German Trance label\r\nDistributed by Music Ma...      Massive Records
#
#    num_of_releases min_release_year max_release_year
# 0               50             1999             2002
# 1                4             1996             1996
# 2               11                0             2002
# 3               29                0             2001
# 4               33             1997             2001

# %%
TABLE_NAME = 'labels'

DB_NAME = "ETL"
DB_USER = "postgres.xpiejfrzvryejvjecyrv"
DB_PASS = "Aryasupa2528#!"
DB_HOST = "aws-0-us-east-1.pooler.supabase.com"
DB_PORT = "6543"

DATABASE_URL = f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/postgres'
engine = create_engine(DATABASE_URL)
engine
# Out:
# Engine(postgresql://postgres.xpiejfrzvryejvjecyrv:***@aws-0-us-east-1.pooler.supabase.com:6543/postgres)

# %%
with engine.connect() as conn:
    labels_df.to_sql("labels", conn, index=False)

# %%
with engine.connect() as conn:
    display(pd.read_sql('SELECT * FROM labels', conn))
# Out:
#           id                                name  \
# 0        774                   Hed Kandi Records
# 1       3141                             Concept
# 2       3203                  Tinnitus Tonträger
# 3       3295                  Taaach! Recordings
# 4       3824                                Fuse
# ..       ...                                 ...
# 425  2731304                ELUSIVE INTELLIGENCE
# 426  2733764                  Axe & Trap Studios
# 427  2786228                              Εν Πλω
# 428  2875724  Doppelkirche Bonn-Schwarzrheindorf
# 429  2990383                          Imp. Nasra
#
#                                            contactinfo  \
# 0    MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 1    Concept Records\r\n24A Barry Street\r\nBradfor...
# 2    Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3    Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 4    Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ..                                                 ...
# 425           childhoodintelligenceworldwide@gmail.com
# 426  Underwood Business Park\r\nWookey Hole Road\r\...
# 427  Κολοκοτρώνη 49, 105 60 Αθήνα\r\n+302103226343 ...
# 428  Doppelkirche St. Maria und St. Clemens\r\nDixs...
# 429               Imp. Nasra\r\n3, Rue Vesoul\r\nTunis
#
#                                                profile  \
# 0    Record company of the UK-based house label [l6...
# 1    Trance label from the UK. The label becomes [l...
# 2            Style: hard kicking minimal techno traxx.
# 3    German Trance Label\r\nDistributed by InterGro...
# 4    German Trance label\r\nDistributed by Music Ma...
# ..                                                 ...
# 425                                               None
# 426  Recording studio located in the city of Wells,...
# 427          Publishing company for books, music etc..
# 428  Catholic parish church in Romanesque style fro...
# 429                Printing company located in Tunisia
#
#                 parentLabel  num_of_releases  min_release_year  \
# 0         Ministry Of Sound               50            1999.0
# 1       Global Beat Records                4            1996.0
# 2                      None               11               0.0
# 3                      None               29               0.0
# 4           Massive Records               33            1997.0
# ..                      ...              ...               ...
# 425  Childhood Intelligence                5            2022.0
# 426                    None               29            2019.0
# 427                    None                1            2021.0
# 428                    None                2               0.0
# 429                    None                1            1972.0
#
#      max_release_year
# 0              2002.0
# 1              1996.0
# 2              2002.0
# 3              2001.0
# 4              2001.0
# ..                ...
# 425            2022.0
# 426            2024.0
# 427            2021.0
# 428               0.0
# 429            1972.0
#
# [430 rows x 8 columns]
